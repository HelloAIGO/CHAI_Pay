# %% [markdown]
# # **연령별 관심사 조사**
#
# 가구주 연령별 가구당 월평균 가계수지 전국 1인이상(https://kosis.kr/index/index.do)

# %%
from sklearn.preprocessing import scale
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib import font_manager
import numpy as np
import pandas as pd

# %% [markdown]
# ## 폰트 변경

# %%
# 폰트 매니저로 폰트 찾기
file_list = font_manager.findSystemFonts()

# %%
# 폰트 이름과 파일 경로 저장
data_list = []

for i in file_list:
        fprop = font_manager.FontProperties(fname = i)
        data_list.append({"name": fprop.get_name(), "file": fprop.get_file()})

df = pd.DataFrame(data_list)
df
# Out:
#                     name                           file
# 0              Agency FB   C:\Windows\Fonts\AGENCYR.TTF
# 1        Microsoft YaHei    C:\Windows\Fonts\msyhbd.ttc
# 2               Ink Free   C:\Windows\Fonts\Inkfree.ttf
# 3          Modern No. 20     C:\Windows\Fonts\MOD20.TTF
# 4                UnDotum   C:\Windows\Fonts\UnDotum.ttf
# ..                   ...                            ...
# 372        HYPost-Medium    C:\Windows\Fonts\H2PORM.TTF
# 373              Candara  C:\Windows\Fonts\Candaraz.ttf
# 374   Rockwell Condensed  C:\Windows\Fonts\ROCCB___.TTF
# 375      Kunstler Script  C:\Windows\Fonts\KUNSTLER.TTF
# 376  Tw Cen MT Condensed  C:\Windows\Fonts\TCCM____.TTF
#
# [377 rows x 2 columns]

# %%
# 폰트가 다른 곳에 저장 되어 있다면 첫 번째 경로 데이터만 저장
font_df = df.groupby('name', as_index = False).first()
font_df
# Out:
#                       name                           file
# 0                Agency FB   C:\Windows\Fonts\AGENCYR.TTF
# 1                 Algerian     C:\Windows\Fonts\ALGER.TTF
# 2                    Ami R   C:\Windows\Fonts\HMKMAMI.TTF
# 3                    Arial    C:\Windows\Fonts\ARIALN.TTF
# 4    Arial Rounded MT Bold   C:\Windows\Fonts\ARLRDBD.TTF
# ..                     ...                            ...
# 205              Wingdings  C:\Windows\Fonts\wingding.ttf
# 206            Wingdings 2  C:\Windows\Fonts\WINGDNG2.TTF
# 207            Wingdings 3  C:\Windows\Fonts\WINGDNG3.TTF
# 208                  Yet R   C:\Windows\Fonts\HMFMOLD.TTF
# 209              Yu Gothic   C:\Windows\Fonts\YuGothM.ttc
#
# [210 rows x 2 columns]

# %%
# 고딕채 선택해서 찾기
font_filtered_df = font_df[font_df['name'].str.contains('Gothic')]
font_filtered_df
# Out:
#                             name                                       file
# 30                Century Gothic              C:\Windows\Fonts\GOTHICBI.TTF
# 38       Copperplate Gothic Bold               C:\Windows\Fonts\COPRGTB.TTF
# 39      Copperplate Gothic Light               C:\Windows\Fonts\COPRGTL.TTF
# 55          Franklin Gothic Book                 C:\Windows\Fonts\FRABK.TTF
# 56          Franklin Gothic Demi                 C:\Windows\Fonts\FRADM.TTF
# 57     Franklin Gothic Demi Cond               C:\Windows\Fonts\FRADMCN.TTF
# 58         Franklin Gothic Heavy               C:\Windows\Fonts\FRAHVIT.TTF
# 59        Franklin Gothic Medium               C:\Windows\Fonts\framdit.ttf
# 60   Franklin Gothic Medium Cond               C:\Windows\Fonts\FRAMDCN.TTF
# 77                HYGothic-Extra                C:\Windows\Fonts\H2GTRE.TTF
# 78               HYGothic-Medium                C:\Windows\Fonts\H2GTRM.TTF
# 119                    MS Gothic              C:\Windows\Fonts\msgothic.ttc
# 128                Malgun Gothic              C:\Windows\Fonts\malgunbd.ttf
# 150                  NanumGothic  C:\Windows\Fonts\NanumGothicExtraBold.ttf
# 182              Showcard Gothic                 C:\Windows\Fonts\SHOWG.TTF
# 209                    Yu Gothic               C:\Windows\Fonts\YuGothM.ttc

# %%
# 폰트 경로 설정
font_path = 'C:/Windows/Fonts/NanumGothicExtraBold.ttf'
font_name = 'NanumGothic'

font_manager.fontManager.addfont(font_path)

# 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'

# %% [markdown]
# ## 데이터 전처리

# %%
# 엑셀 파일 불러오기
xlsx_file = '가구주_연령별_가구당_월평균_가계수지__전국_1인이상__20230531135713.xlsx'

# %%
df = pd.read_excel(xlsx_file)

# %%
df.head()
# Out:
#   가구주연령별    가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4 Unnamed: 6  \
# 0    NaN        NaN     전체가구      근로자가구     근로자외가구     전체가구      근로자가구
# 1  전체 평균   가구원수 (명)     2.33       2.44       2.16     2.27       2.39
# 2    NaN  가구주연령 (세)    52.27      47.73      59.56    52.73      47.73
# 3    NaN   가구분포 (%)      100        100        100      100        100
# 4    NaN         소득  4833575    5464131    3822462  5053853    6055393
#
#   Unnamed: 7
# 0     근로자외가구
# 1       2.09
# 2      60.41
# 3        100
# 4    3517428

# %%
csv_file = 'csv_file.xlsx'

# %%
# csv 파일로 변경
df.to_csv(csv_file, index=False)

# %%
df1 = pd.read_csv('csv_file.csv')

# %%
# 데이터 확인
df1.head()
# Out:
#   가구주연령별    가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4 Unnamed: 6  \
# 0    NaN        NaN     전체가구      근로자가구     근로자외가구     전체가구      근로자가구
# 1  전체 평균   가구원수 (명)     2.33       2.44       2.16     2.27       2.39
# 2    NaN  가구주연령 (세)    52.27      47.73      59.56    52.73      47.73
# 3    NaN   가구분포 (%)      100        100        100      100        100
# 4    NaN         소득  4833575    5464131    3822462  5053853    6055393
#
#   Unnamed: 7
# 0     근로자외가구
# 1       2.09
# 2      60.41
# 3        100
# 4    3517428

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   가구주연령별      6 non-null      object
#  1   가계수지항목별     174 non-null    object
#  2   2022.4/4    175 non-null    object
#  3   Unnamed: 3  175 non-null    object
#  4   Unnamed: 4  175 non-null    object
#  5   2023.1/4    175 non-null    object
#  6   Unnamed: 6  175 non-null    object
#  7   Unnamed: 7  175 non-null    object
# dtypes: object(8)
# memory usage: 11.1+ KB

# %%
# '가구주연령별'행의 칼럼을 나이별로 구하기 위해 Nat a Number 값을 바로 아래 값으로 채워준다.
df['가구주연령별'].fillna(method='ffill', inplace=True)
df
# Out:
#        가구주연령별     가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4 Unnamed: 6  \
# 0         NaN         NaN     전체가구      근로자가구     근로자외가구     전체가구      근로자가구
# 1       전체 평균    가구원수 (명)     2.33       2.44       2.16     2.27       2.39
# 2       전체 평균   가구주연령 (세)    52.27      47.73      59.56    52.73      47.73
# 3       전체 평균    가구분포 (%)      100        100        100      100        100
# 4       전체 평균          소득  4833575    5464131    3822462  5053853    6055393
# ..        ...         ...      ...        ...        ...      ...        ...
# 170  65세이상 가구       비소비지출   427982     488989     401667   522167     602135
# 171  65세이상 가구      처분가능소득  2562224    2955320    2392666  2292820    2948472
# 172  65세이상 가구         흑자액   829031    1102283     711166   507189     919140
# 173  65세이상 가구     흑자율 (%)     32.4       37.3       29.7     22.1       31.2
# 174  65세이상 가구  평균소비성향 (%)     67.6       62.7       70.3     77.9       68.8
#
#     Unnamed: 7
# 0       근로자외가구
# 1         2.09
# 2        60.41
# 3          100
# 4      3517428
# ..         ...
# 170     491099
# 171    2038102
# 172     347147
# 173         17
# 174         83
#
# [175 rows x 8 columns]

# %%
# 데이터 확인
df1['가구주연령별'].unique()
# Out:
# array([nan, '전체 평균', '39세이하가구', '40~49세가구', '50~59세가구', '60세이상 가구',
#        '65세이상 가구'], dtype=object)

# %%
# 39세이하가구 데이터 추출
Group_df1 = df[df['가구주연령별'] == '39세이하가구']
Group_df1
# Out:
#      가구주연령별          가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4  \
# 30  39세이하가구         가구원수 (명)     2.01       2.02       1.99     1.91
# 31  39세이하가구        가구주연령 (세)    32.06      32.22      31.42    31.63
# 32  39세이하가구         가구분포 (%)     23.4       30.2      12.48    22.91
# 33  39세이하가구               소득  4345025    4624279    3261465  4869789
# 34  39세이하가구             경상소득  4278107    4555756    3200777  4797287
# 35  39세이하가구             근로소득  3387106    4199040    236,647  3846150
# 36  39세이하가구             사업소득   582432     109284    2418336   498213
# 37  39세이하가구             재산소득    4,317      3,950      5,744    4,158
# 38  39세이하가구             이전소득   304252     243482     540050   448765
# 39  39세이하가구            비경상소득    66918      68523     60,688   72,502
# 40  39세이하가구             가계지출  3364388    3457958    3001318  3553449
# 41  39세이하가구             소비지출  2538482    2522363    2601024  2611387
# 42  39세이하가구   01.식료품 · 비주류음료   267599     271825     251200   258231
# 43  39세이하가구       02.주류 · 담배    41156      41241      40828    37438
# 44  39세이하가구       03.의류 · 신발   174943     178227     162201   135288
# 45  39세이하가구  04.주거 · 수도 · 광열   294075     277441     358616   402361
# 46  39세이하가구  05.가정용품 · 가사서비스   115158     120462      94577   124357
# 47  39세이하가구            06.보건   140403     136278     156407   158609
# 48  39세이하가구            07.교통   357326     338885    428,883   283411
# 49  39세이하가구            08.통신   130444     131612     125914   125020
# 50  39세이하가구       09.오락 · 문화   197396     195986     202864   233443
# 51  39세이하가구            10.교육   134298     126289     165373   145676
# 52  39세이하가구       11.음식 · 숙박   487988     502757     430681   485462
# 53  39세이하가구    12.기타상품 · 서비스   197696     201360     183480   222093
# 54  39세이하가구            비소비지출   825906     935595     400294   942062
# 55  39세이하가구           처분가능소득  3519119    3688685    2861170  3927727
# 56  39세이하가구              흑자액   980637    1166321     260146  1316339
# 57  39세이하가구          흑자율 (%)     27.9       31.6        9.1     33.5
# 58  39세이하가구       평균소비성향 (%)     72.1       68.4       90.9     66.5
#
#    Unnamed: 6 Unnamed: 7
# 30        1.9       1.95
# 31      31.61      31.71
# 32      30.03         12
# 33    5291478    3250282
# 34    5229988    3135489
# 35    4759427     338692
# 36      77262    2114883
# 37      3,699      5,923
# 38     389600     675991
# 39     61,490    114,793
# 40    3754594    2780949
# 41    2677431    2357747
# 42     259926     251717
# 43      38635      32840
# 44     142491     107621
# 45     399268     414238
# 46     135715      80734
# 47     155081     172157
# 48     303049     207994
# 49     124434     127270
# 50     244658     190373
# 51     139800     168244
# 52     504520     412271
# 53     229853     192288
# 54    1077163     423203
# 55    4214315    2827080
# 56    1536884     469333
# 57       36.5       16.6
# 58       63.5       83.4

# %%
# 40대가구 데이터 추출
Group_df2 = df[df['가구주연령별'] == '40~49세가구']
Group_df2
# Out:
#       가구주연령별          가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4  \
# 59  40~49세가구         가구원수 (명)     3.04       3.06          3        3
# 60  40~49세가구        가구주연령 (세)    44.48      44.36      44.86    44.49
# 61  40~49세가구         가구분포 (%)    20.36         25       12.9    19.51
# 62  40~49세가구               소득  6063190    6397084    5025803  6661819
# 63  40~49세가구             경상소득  5981972    6311641    4957713  6542460
# 64  40~49세가구             근로소득  4495444    5716997     700159  5043362
# 65  40~49세가구             사업소득  1092233     274738    3632135   873587
# 66  40~49세가구             재산소득    6,456      7,732      2,493   13,446
# 67  40~49세가구             이전소득   387839     312174     622926   612065
# 68  40~49세가구            비경상소득    81218      85443     68,091  119,358
# 69  40~49세가구             가계지출  4861590    5140452    3995185  5271521
# 70  40~49세가구             소비지출  3588434    3708953    3213989  3752849
# 71  40~49세가구   01.식료품 · 비주류음료   456817     463530     435959   450972
# 72  40~49세가구       02.주류 · 담배    45717      45911      45113    45926
# 73  40~49세가구       03.의류 · 신발   236575     243861     213937   186233
# 74  40~49세가구  04.주거 · 수도 · 광열   310056     310366     309096   425533
# 75  40~49세가구  05.가정용품 · 가사서비스   149312     143602     167052   129548
# 76  40~49세가구            06.보건   227127     237459     195026   259247
# 77  40~49세가구            07.교통   468331     522340     300528   465865
# 78  40~49세가구            08.통신   167121     170455     156762   173197
# 79  40~49세가구       09.오락 · 문화   229830     227194     238019   236328
# 80  40~49세가구            10.교육   498495     518874     435176   584727
# 81  40~49세가구       11.음식 · 숙박   537317     556107     478938   525844
# 82  40~49세가구    12.기타상품 · 서비스   261738     269255     238382   269429
# 83  40~49세가구            비소비지출  1273157    1431499     781197  1518672
# 84  40~49세가구           처분가능소득  4790033    4965584    4244607  5143146
# 85  40~49세가구              흑자액  1201599    1256632    1030618  1390297
# 86  40~49세가구          흑자율 (%)     25.1       25.3       24.3       27
# 87  40~49세가구       평균소비성향 (%)     74.9       74.7       75.7       73
#
#    Unnamed: 6 Unnamed: 7
# 59       3.02       2.93
# 60      44.36      44.91
# 61      24.77      11.43
# 62    7229405    4774911
# 63    7085915    4735777
# 64    6312720     823454
# 65     238121    2986159
# 66     16,250      4,125
# 67     518824     922038
# 68    143,490     39,135
# 69    5572708    4270242
# 70    3874218    3349365
# 71     456675     432010
# 72      46899      42692
# 73     187783     181079
# 74     418299     449582
# 75     134298     113757
# 76     253382     278744
# 77     512746     310014
# 78     174836     167749
# 79     252463     182689
# 80     606379     512747
# 81     553147     435077
# 82     277311     243224
# 83    1698491     920878
# 84    5530914    3854034
# 85    1656696     504669
# 86         30       13.1
# 87         70       86.9

# %%
# '가계수지항목별'에서 원하는 소비 종류를 찾기위해 앞에 번호가 적혀있는 행만 추출
filtered_df1 = Group_df1[Group_df1['가계수지항목별'].str.match('^\d') & ~df['가계수지항목별'].isna()]
filtered_df1.head()
# Out:
# C:\Users\rhlab\AppData\Local\Temp\ipykernel_25304\3141115001.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df1 = Group_df1[Group_df1['가계수지항목별'].str.match('^\d') & ~df['가계수지항목별'].isna()]
#      가구주연령별          가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4  \
# 42  39세이하가구   01.식료품 · 비주류음료   267599     271825     251200   258231
# 43  39세이하가구       02.주류 · 담배    41156      41241      40828    37438
# 44  39세이하가구       03.의류 · 신발   174943     178227     162201   135288
# 45  39세이하가구  04.주거 · 수도 · 광열   294075     277441     358616   402361
# 46  39세이하가구  05.가정용품 · 가사서비스   115158     120462      94577   124357
#
#    Unnamed: 6 Unnamed: 7
# 42     259926     251717
# 43      38635      32840
# 44     142491     107621
# 45     399268     414238
# 46     135715      80734

# %%
filtered_df2 = Group_df2[Group_df2['가계수지항목별'].str.match('^\d') & ~df['가계수지항목별'].isna()]
filtered_df2.head()
# Out:
# C:\Users\rhlab\AppData\Local\Temp\ipykernel_25304\2111520233.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df2 = Group_df2[Group_df2['가계수지항목별'].str.match('^\d') & ~df['가계수지항목별'].isna()]
#       가구주연령별          가계수지항목별 2022.4/4 Unnamed: 3 Unnamed: 4 2023.1/4  \
# 71  40~49세가구   01.식료품 · 비주류음료   456817     463530     435959   450972
# 72  40~49세가구       02.주류 · 담배    45717      45911      45113    45926
# 73  40~49세가구       03.의류 · 신발   236575     243861     213937   186233
# 74  40~49세가구  04.주거 · 수도 · 광열   310056     310366     309096   425533
# 75  40~49세가구  05.가정용품 · 가사서비스   149312     143602     167052   129548
#
#    Unnamed: 6 Unnamed: 7
# 71     456675     432010
# 72      46899      42692
# 73     187783     181079
# 74     418299     449582
# 75     134298     113757

# %%
# 빈 칼럼 삭제
filtered_df1.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7'],axis=1, inplace=True,errors='ignore')
filtered_df1
# Out:
# C:\Users\rhlab\AppData\Local\Temp\ipykernel_25304\234877890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df1.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7'],axis=1, inplace=True,errors='ignore')
#      가구주연령별          가계수지항목별 2022.4/4 2023.1/4
# 42  39세이하가구   01.식료품 · 비주류음료   267599   258231
# 43  39세이하가구       02.주류 · 담배    41156    37438
# 44  39세이하가구       03.의류 · 신발   174943   135288
# 45  39세이하가구  04.주거 · 수도 · 광열   294075   402361
# 46  39세이하가구  05.가정용품 · 가사서비스   115158   124357
# 47  39세이하가구            06.보건   140403   158609
# 48  39세이하가구            07.교통   357326   283411
# 49  39세이하가구            08.통신   130444   125020
# 50  39세이하가구       09.오락 · 문화   197396   233443
# 51  39세이하가구            10.교육   134298   145676
# 52  39세이하가구       11.음식 · 숙박   487988   485462
# 53  39세이하가구    12.기타상품 · 서비스   197696   222093

# %%
filtered_df2.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7'],axis=1, inplace=True,errors='ignore')
filtered_df2
# Out:
# C:\Users\rhlab\AppData\Local\Temp\ipykernel_25304\179707722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df2.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 6','Unnamed: 7'],axis=1, inplace=True,errors='ignore')
#       가구주연령별          가계수지항목별 2022.4/4 2023.1/4
# 71  40~49세가구   01.식료품 · 비주류음료   456817   450972
# 72  40~49세가구       02.주류 · 담배    45717    45926
# 73  40~49세가구       03.의류 · 신발   236575   186233
# 74  40~49세가구  04.주거 · 수도 · 광열   310056   425533
# 75  40~49세가구  05.가정용품 · 가사서비스   149312   129548
# 76  40~49세가구            06.보건   227127   259247
# 77  40~49세가구            07.교통   468331   465865
# 78  40~49세가구            08.통신   167121   173197
# 79  40~49세가구       09.오락 · 문화   229830   236328
# 80  40~49세가구            10.교육   498495   584727
# 81  40~49세가구       11.음식 · 숙박   537317   525844
# 82  40~49세가구    12.기타상품 · 서비스   261738   269429

# %%
# 파이 차트 색깔별 종류
plt.pie(filtered_df1['2022.4/4'], labels=filtered_df1['가계수지항목별'])
plt.legend(filtered_df1['가계수지항목별'])

# %%
# 퍼짐 정도 값 설정
exp = [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01]

# %%
# 39세 이하 관심사 차트 
plt.pie(filtered_df1['2022.4/4'], labels=filtered_df1['가계수지항목별'],startangle=90, explode=exp, autopct='%.1f%%')
plt.title('-39세 이하 관심사-')
# Out:
# Text(0.5, 1.0, '-39세 이하 관심사-')

# %%
# 40대 관심사 차트
plt.pie(filtered_df1['2022.4/4'], labels=filtered_df1['가계수지항목별'], startangle=90, explode=exp, autopct='%.1f%%')
plt.title('-40~49세 관심사-')
# Out:
# Text(0.5, 1.0, '-40~49세 관심사-')
